# %%
import pandas as pd
import json
import os
jsfile = pd.read_json('/home/elad/PycharmProjects/config_generator/data/afterclean.json')
pd.set_option('display.max_columns', None)
pd.set_option('max_rows', None)
duperows = jsfile[jsfile.duplicated(['name', 'mountpoint'])]
jssorted = jsfile.sort_values(by=['name', 'mountpoint'])
result = jssorted.drop_duplicates(subset=['name'], ignore_index=True)
result
output = result.to_json(orient="records")
parsed = json.loads(output)
outfile = "/home/elad/PROJEKT/outfile.json"
with open(outfile, 'w') as outf:
    outf.write(json.dumps(dict(stations=parsed), indent=2))
    outf.close()
# Out:
#                         caster                extra_labels         group  \
# 0               www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 1   cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 2               www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 3   cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 4   cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 5   cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 6   cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 7   cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 8   cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 9               www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 10  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 11              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 12  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 13  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 14  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 15  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 16  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 17  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 18              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 19  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 20              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 21  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 22  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 23  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 24  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 25  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 26  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 27  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 28  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 29  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 30              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 31  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 32  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 33  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 34  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 35  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 36  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 37              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 38  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 39  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 40  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 41              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 42  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 43  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 44  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 45              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 46  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 47  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 48              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 49              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 50  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 51  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 52  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 53              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 54              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 55  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 56  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 57  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 58  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 59  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
# 60              www.igs-ip.net    {'caster': 'igs-ip-net'}    igs-ip-net
# 61  cddis-caster.gsfc.nasa.gov  {'caster': 'cddis-caster'}  cddis-caster
#
#     mountpoint  name  port  secure            user         password
# 0   ABMF00GLP0  ABMF    80   False        [gevbh1]       [Gr190511]
# 1   ACRG00GHA0  ACRG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 2   ALBH00CAN0  ALBH    80   False        [gevbh1]       [Gr190511]
# 3   ALGO00CAN0  ALGO   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 4   AREG00PER0  AREG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 5   ASCG00SHN0  ASCG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 6   AUCK00NZL0  AUCK   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 7   BIK000KGZ0  BIK0   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 8   BRST00FRA0  BRST   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 9   BRUX00BEL0  BRUX    80   False        [gevbh1]       [Gr190511]
# 10  CAS100ATA0  CAS1   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 11  CCJ200JPN0  CCJ2    80   False        [gevbh1]       [Gr190511]
# 12  CHPG00BRA0  CHPG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 13  COCO00AUS0  COCO   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 14  CPVG00CPV0  CPVG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 15  CUT000AUS0  CUT0   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 16  DARW00AUS0  DARW   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 17  DJIG00DJI0  DJIG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 18  DUMG00ATA0  DUMG    80   False        [gevbh1]       [Gr190511]
# 19  DYNG00GRC0  DYNG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 20  ENAO00PRT0  ENAO    80   False        [gevbh1]       [Gr190511]
# 21  GAMB00PYF0  GAMB   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 22  GAMG00KOR0  GAMG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 23  HARB00ZAF0  HARB   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 24  JFNG00CHN0  JFNG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 25  KERG00ATF0  KERG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 26  KIR000SWE0  KIR0   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 27  LPAL00ESP0  LPAL   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 28  MAC100AUS0  MAC1   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 29  MAJU00MHL0  MAJU   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 30  MAO000USA0  MAO0    80   False        [gevbh1]       [Gr190511]
# 31  MAW100ATA0  MAW1   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 32  MAYG00MYT0  MAYG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 33  METG00FIN0  METG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 34  MOBS00AUS0  MOBS   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 35  NICO00CYP0  NICO   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 36  NKLG00GAB0  NKLG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 37  NRC100CAN0  NRC1    80   False        [gevbh1]       [Gr190511]
# 38  OBE400DEU0  OBE4   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 39  OHI300ATA0  OHI3   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 40  OWMG00NZL0  OWMG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 41  PRDS00CAN0  PRDS    80   False        [gevbh1]       [Gr190511]
# 42  PTGG00PHL0  PTGG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 43  REUN00REU0  REUN   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 44  REYK00ISL0  REYK   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 45  RGDG00ARG0  RGDG    80   False        [gevbh1]       [Gr190511]
# 46  RIO200ARG0  RIO2   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 47  SALU00BRA0  SALU   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 48  SASK00CAN0  SASK    80   False        [gevbh1]       [Gr190511]
# 49  SCH200CAN0  SCH2    80   False        [gevbh1]       [Gr190511]
# 50  SEYG00SYC0  SEYG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 51  SGOC00LKA0  SGOC   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 52  SGPO00USA0  SGPO   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 53  SOD300FIN0  SOD3    80   False        [gevbh1]       [Gr190511]
# 54  STJO00CAN0  STJO    80   False        [gevbh1]       [Gr190511]
# 55  TLSE00FRA0  TLSE   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 56  TONG00TON0  TONG   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 57  ULAB00MNG0  ULAB   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 58  UNSA00ARG0  UNSA   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 59  UTQI00USA0  UTQI   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
# 60  YELL00CAN0  YELL    80   False        [gevbh1]       [Gr190511]
# 61  ZIM200CHE0  ZIM2   443    True  [gbenhaimlear]  [onx@foVEA9@9G]
